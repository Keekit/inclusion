# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pycountry

# %%
data = pd.read_csv("C:\\Users\\corre\\Desktop\\Wild Code School\\Hackathon\\DEI Dataset.csv")

# %%
data.shape
# Out:
# (10000, 45)

# %%
data.columns
# Out:
# Index(['Id', 'Name', 'Surname', 'Division', 'Manager', 'Gender',
#        'Sexual_Orientation', 'LGBTQ', 'Indigenous', 'Ethnicity', 'Disability',
#        'Minority', 'Veteran', 'Date of Birth', 'Age', 'Preferred Name',
#        'Nationality', 'Hobbies', 'Pronouns', 'Mobile Number', 'Email',
#        'Aug_D_Q1', 'Aug_D_Q2', 'Aug_D_Q3', 'Aug_D_Q4', 'Aug_D_Q5',
#        'D_Negative', 'D_Neutral', 'D_Positive', 'Aug_E_Q1', 'Aug_E_Q2',
#        'Aug_E_Q3', 'Aug_E_Q4', 'Aug_E_Q5', 'E_Negative', 'E_Neutral',
#        'E_Positive', 'Aug_I_Q1', 'Aug_I_Q2', 'Aug_I_Q3', 'Aug_I_Q4',
#        'Aug_I_Q5', 'I_Negative', 'I_Neutral', 'I_Positive'],
#       dtype='object')

# %%
data.head()
# Out:
#    Id      Name   Surname   Division Manager       Gender Sexual_Orientation  \
# 0   1   Deborah   Addison         IT      No  Transgender       Heterosexual
# 1   2      Mona      Hill  Marketing      No         Male       Heterosexual
# 2   3  Kimberly   Shelton    Finance      No       Female       Heterosexual
# 3   4     Denis  Robinson         HR      No         Male       Heterosexual
# 4   5    Carmen      Gunn         RD      No         Male       Heterosexual
#
#                LGBTQ Indigenous Ethnicity  ... E_Neutral E_Positive Aug_I_Q1  \
# 0  Prefer not to say         No     White  ...         1          2        0
# 1                 No        Yes     White  ...         2          3        0
# 2                 No         No     White  ...         0          4       -2
# 3                 No         No     White  ...         1          3        0
# 4                 No         No     Asian  ...         0          5        1
#
# ...

# %%
data['Division'].unique()
# Out:
# array(['IT', 'Marketing', 'Finance', 'HR', 'RD', 'Sales', 'Operations'],
#       dtype=object)

# %%
'''
    Question :  Nom > srt
                Prénom > srt
                Service > selection : IT - Sales - Rh - Finances - Marketing -Opération -Hr
                Manager > bool > Yes / No
                Gender > F - H - Non bineaire - not to say
                Lgbtq > Y N Not to say
                Nationalité > str
                
                Age > int
                email > str
                Mobile > int

                Dans le formulaire de connaissance employé
'''
# Out:
# '\n    Question :  Nom > srt\n                Prénom > srt\n                Service > selection : IT - Sales - Rh - Finances - Marketing -Opération -Hr\n                Manager > bool > Yes / No\n                Gender > F - H - Non bineaire - not to say\n                Lgbtq > Y N Not to say\n                Nationalité > str\n                \n                Age > int\n                email > str\n                Mobile > int\n\n                Dans le formulaire de connaissance employé\n'

# %%
colonnes = ['Name', 'Surname', 'Division', 'Manager', 'Gender', 'LGBTQ', 'Nationality', 'Ethnicity', 'Disability', 'Age', 'Mobile Number', 'Email']

# Sélectionner seulement les colonnes listées dans 'colonnes'
data = data[colonnes]

# %%
''' Deja dans la database : Handicap > Y N Not to say
                            Lgbtq > Y N Not to say
                            Origine ethnique : european, asian, african, american, other > a voir si on la met
                            
'''
# Out:
# ' Deja dans la database : Handicap > Y N Not to say\n                            Lgbtq > Y N Not to say\n                            Origine ethnique : european, asian, african, american, other > a voir si on la met\n                            \n'

# %%
''''# Questions binaires
questions_binaires = [
    "Avez vous deja été victime/temoin de harcelement sexuel ?",
    "Avez vous deja été victime/temoin de discrimination raciale ?",
    "Avez-vous déjà été témoin ou victime de discrimination fondée sur le genre au travail ?",
    "Avez-vous déjà été témoin ou victime de discrimination fondée sur l'âge au travail ?",
    "Avez-vous déjà été témoin ou victime de discrimination basée sur votre état de santé ou handicap au travail ?",
    "Avez-vous déjà ressenti une situation de harcèlement moral ou psychologique au travail ?",
    "Vous sentez-vous respecté(e) et entendu(e) par vos collègues et votre hiérarchie ?",
    "Vous sentez-vous en mesure de signaler en toute sécurité des préoccupations concernant des comportements inappropriés au travail ?"
]

# Questions numériques (échelle de 1 à 10)
questions_numeriques = [
    # Bien etre au travail
    "Vous sentez vous en securité au travail ? (1 à 10)",
    "Comment évaluez-vous votre niveau de stress au travail ? (1 à 10)",
    "Vous sentez vous heureux au travail ? (1 à 10)",

    # Discrimination
    "Vous arrive-t-il de ressentir des préjugés inconscients au sein de notre culture d’entreprise ? (1 à 10)",
    "Sur une échelle de 1 à 10, dans quelle mesure notre entreprise promeut-elle un environnement inclusif sans distinction d’orientation sexuelle, de race, d’âge, de nationalité ou de handicap ?",
    "Estimez vous que l'égalité est respectée au sein de votre entreprise ? (1 à 10)",
    "Dans quelle mesure diriez-vous que votre entreprise valorise la diversité et l'inclusion ? (1 à 10)",
    "Comment évaluez-vous la qualité des relations avec vos collègues de travail ? (1 à 10)",

    # Prévention 

    "Dans quelle mesure pensez-vous que les salaires et les récompenses sont équitables au sein de votre entreprise ? (1 à 10)",
    "Êtes-vous satisfait(e) des opportunités de développement professionnel qui vous sont offertes ? (1 à 10)"
]

# Question à réponse libre
question_libre = "Avez-vous des idées sur la manière dont notre direction pourrait améliorer l'inclusion dans notre culture d’entreprise ?"

# Générer des réponses aléatoires pour 10000 lignes
data_binaires = {    "Vous sentez-vous apprécié pour le travail que vous accomplissez, indépendamment de votre identité sexuelle, de votre race, de votre handicap ou de votre nationalité ? (1 à 10)",

    question: np.random.choice(['Oui', 'Non'], size=10000)
    for question in questions_binaires
}

data_numeriques = {
    question: np.random.randint(1, 11, size=10000)
    for question in questions_numeriques
}

# Génération de réponses aléatoires pour la question libre
responses_libres = [
    "Je pense que la direction pourrait organiser plus de formations sur la diversité.",
    "Encourager la participation à des groupes de discussion sur l'inclusion.",
    "Proposer des événements culturels pour sensibiliser à la diversité.",
    "Promouvoir des politiques de recrutement inclusives.",
    "Améliorer la communication interculturelle au sein de l'entreprise.",
    np.nan  # Pour introduire des valeurs NaN aléatoires
]

# Utiliser np.random.choice pour mélanger les réponses libres avec NaN
data_libre = {
    question_libre: np.random.choice(responses_libres, size=10000)
}

# Créer les DataFrames à partir des données générées aléatoirement
df_binaires = pd.DataFrame(data_binaires)
df_numeriques = pd.DataFrame(data_numeriques)
df_libre = pd.DataFrame(data_libre)

# Concaténer les DataFrames
data = pd.concat([data, df_binaires, df_numeriques, df_libre], axis=1)'''
# Out:
# '\'# Questions binaires\nquestions_binaires = [\n    "Avez vous deja été victime/temoin de harcelement sexuel ?",\n    "Avez vous deja été victime/temoin de discrimination raciale ?",\n    "Avez-vous déjà été témoin ou victime de discrimination fondée sur le genre au travail ?",\n    "Avez-vous déjà été témoin ou victime de discrimination fondée sur l\'âge au travail ?",\n    "Avez-vous déjà été témoin ou victime de discrimination basée sur votre état de santé ou handicap au travail ?",\n    "Avez-vous déjà ressenti une situation de harcèlement moral ou psychologique au travail ?",\n    "Vous sentez-vous respecté(e) et entendu(e) par vos collègues et votre hiérarchie ?",\n    "Vous sentez-vous en mesure de signaler en toute sécurité des préoccupations concernant des comportements inappropriés au travail ?"\n]\n\n# Questions numériques (échelle de 1 à 10)\nquestions_numeriques = [\n    # Bien etre au travail\n    "Vous sentez vous en securité au travail ? (1 à 10)",\n    "Comment éval
# ...

# %%
questions = [
    "Votre entreprise propose-t-elle des formations régulières sur la diversité et l'inclusion pour tous les employés ?",
    "L'entreprise dispose-t-elle de politiques claires et accessibles concernant la lutte contre la discrimination et le harcèlement ?",
    "Avez-vous accès à une personne de contact ou à un service dédié pour signaler les incidents de discrimination ou de harcèlement ?"
]


weights_bool = [0.2, 0.8]  # Corrected weights list

# Génération de données aléatoires pour les réponses binaires
data_bool = {
    question: np.random.choice(['Oui', 'Non'], size=10000, p=weights_bool)
    for question in questions
}

# Questions binaires
questions_binaires = [
    "Avez-vous déjà été victime/témoin de harcèlement sexuel ?",
    "Avez-vous déjà été victime/témoin de discrimination raciale ?",
    "Avez-vous déjà été témoin ou victime de discrimination fondée sur le genre au travail ?",
    "Avez-vous déjà été témoin ou victime de discrimination fondée sur l'âge au travail ?",
    "Avez-vous déjà été témoin ou victime de discrimination fondée sur le genre ou l’orientation sexuelle ?",
    "Avez-vous déjà été témoin ou victime de discrimination fondée sur votre religion, culture ?",
    "Avez-vous déjà été témoin ou victime de discrimination basée sur votre état de santé ou handicap au travail ?",
    "Avez-vous déjà été témoin ou victime de discrimination basée sur votre parentalité ou future parentalité ?",
    "Avez-vous déjà ressenti une situation de harcèlement moral ou psychologique au travail ?",
    "Vous sentez-vous en mesure de signaler en toute sécurité des préoccupations concernant des comportements inappropriés au travail ?",    
]

# Questions numériques (échelle de 1 à 10)
questions_numeriques = [
    "Dans le cas où vous avez déjà fait un signalement, comment jugez-vous le traitement de votre plainte ? (1 à 10, 10 étant totalement satisfait)",
    "Estimez-vous que l'égalité est respectée au sein de votre entreprise ? (1 à 10)",
    "Dans quelle mesure diriez-vous que votre entreprise valorise la diversité et l'inclusion ? (1 à 10)",
    "Vous sentez-vous apprécié pour le travail que vous accomplissez, indépendamment de votre identité sexuelle, de votre race, de votre handicap ou de votre nationalité ? (1 à 10)",
    "Vous sentez-vous heureux au travail ? (1 à 10, 10 étant la meilleure note)",
    "Vous sentez-vous en sécurité au travail ? (1 à 10, 10 étant la meilleure note)",
    "Comment évaluez-vous votre niveau de stress au travail ? (1 à 10, où 10 représente le plus faible niveau de stress)",
    "Comment évaluez-vous la qualité des relations avec vos collègues de travail ? (1 à 10, 10 étant la meilleure note)",
    "Recommanderiez-vous l’entreprise à un proche ? (1 à 10, 10 tout à fait)",
    "Vous sentez-vous respecté(e) et entendu(e) par vos collègues et votre hiérarchie ? (1 à 10)",
    "Pensez-vous que votre entreprise valorise et promeut activement un environnement de travail inclusif ? (1 à 10, 10 tout à fait)",
    "Pensez-vous que la direction et les managers de votre entreprise sont engagés et responsables en matière de diversité et d'inclusion ? (1 à 10, 10 tout à fait)"
]

# Question à réponse libre
questions_libres = [
    "Selon vous, quelles mesures l'entreprise devrait-elle prendre pour mieux prévenir et gérer les discriminations ?",
]

weights_binaire = [0.2, 0.3, 0.2, 0.2, 0.1]  # Exemple de poids pour chaque réponse

# Génération de données aléatoires pour les réponses binaires
data_binaires = {
    question: np.random.choice(['Jamais', 'Rarement', 'Parfois', 'Souvent', 'Régulièrement'], size=10000, p=weights_binaire)
    for question in questions_binaires
}

# Poids correspondants aux réponses numériques
weights_numeriques = [0.02, 0.03, 0.05, 0.05, 0.1, 0.1, 0.15, 0.2, 0.2, 0.1]  # Exemple de poids pour chaque réponse

# Génération de données aléatoires pour les réponses numériques en tenant compte des poids
data_numeriques = {
    question: np.random.choice(np.arange(1, 11), size=10000, p=weights_numeriques)
    for question in questions_numeriques
}

# Génération de réponses aléatoires pour les questions à réponse libre
responses_libres = [
    "Proposer des formations régulières sur la diversité et l'inclusion.",
    "Promouvoir des politiques de tolérance zéro contre la discrimination.",
    "Créer un comité dédié à la diversité pour superviser les initiatives inclusives.",
    "Renforcer la sensibilisation à la diversité par des événements culturels et des formations interculturelles.",
    "Améliorer la transparence dans le traitement des signalements de discrimination.",
    "Mettre en place un programme de mentorat pour favoriser l'intégration et l'avancement des minorités."
]

# Poids correspondants aux réponses
weights_libres = [0.3, 0.2, 0.1, 0.1, 0.1, 0.2]  # Exemple de poids pour chaque réponse

# Génération aléatoire des réponses en tenant compte des poids
data_libres = {
    "Selon vous, quelles mesures l'entreprise devrait-elle prendre pour mieux prévenir et gérer les discriminations ?": np.random.choice(responses_libres, size=10000, p=weights_libres)
}

# Création des DataFrames à partir des données générées aléatoirement
df_binaires = pd.DataFrame(data_binaires)
df_numeriques = pd.DataFrame(data_numeriques)
df_libres = pd.DataFrame(data_libres)
df_bool = pd.DataFrame(data_bool)
# Concaténation des DataFrames
data = pd.concat([data, df_binaires, df_numeriques, df_libres, df_bool], axis=1)

# %%
data['Salaire_Annuel'] = np.random.randint(13200, 90000, size=10000)

# %%
data.head()
# Out:
#        Name   Surname   Division Manager       Gender              LGBTQ  \
# 0   Deborah   Addison         IT      No  Transgender  Prefer not to say
# 1      Mona      Hill  Marketing      No         Male                 No
# 2  Kimberly   Shelton    Finance      No       Female                 No
# 3     Denis  Robinson         HR      No         Male                 No
# 4    Carmen      Gunn         RD      No         Male                 No
#
#   Nationality Ethnicity Disability  Age  ...  \
# 0      Polish     White        Yes   29  ...
# 1         Lao     White         No   59  ...
# 2    Canadian     White         No   43  ...
# 3    Canadian     White        Yes   44  ...
# 4      Korean     Asian         No   50  ...
#
#   Vous sentez-vous heureux au travail ? (1 à 10, 10 étant la meilleure note)  \
# 0                                                  4
# 1                                                  6
# 2                                                  9
# ...

# %%
# Définition de la correspondance points / réponses
points_mapping = {
    'Jamais': 10,
    'Rarement': 8,
    'Parfois': 6,
    'Souvent': 4,
    'Régulièrement': 0
}

# Création de nouvelles colonnes pour les points attribués
for question in questions_binaires:
    new_column_name = f"{question} - Points"
    data_binaires[new_column_name] = [points_mapping[response] for response in data_binaires[question]]

# %%
data.head()
# Out:
#        Name   Surname   Division Manager       Gender              LGBTQ  \
# 0   Deborah   Addison         IT      No  Transgender  Prefer not to say
# 1      Mona      Hill  Marketing      No         Male                 No
# 2  Kimberly   Shelton    Finance      No       Female                 No
# 3     Denis  Robinson         HR      No         Male                 No
# 4    Carmen      Gunn         RD      No         Male                 No
#
#   Nationality Ethnicity Disability  Age  ...  \
# 0      Polish     White        Yes   29  ...
# 1         Lao     White         No   59  ...
# 2    Canadian     White         No   43  ...
# 3    Canadian     White        Yes   44  ...
# 4      Korean     Asian         No   50  ...
#
#   Vous sentez-vous heureux au travail ? (1 à 10, 10 étant la meilleure note)  \
# 0                                                  4
# 1                                                  6
# 2                                                  9
# ...

# %%
data.shape
# Out:
# (10000, 36)

# %%
data.head()
# Out:
#        Name   Surname   Division Manager       Gender              LGBTQ  \
# 0   Deborah   Addison         IT      No  Transgender  Prefer not to say
# 1      Mona      Hill  Marketing      No         Male                 No
# 2  Kimberly   Shelton    Finance      No       Female                 No
# 3     Denis  Robinson         HR      No         Male                 No
# 4    Carmen      Gunn         RD      No         Male                 No
#
#   Nationality Ethnicity Disability  Age  ...  \
# 0      Polish     White        Yes   29  ...
# 1         Lao     White         No   59  ...
# 2    Canadian     White         No   43  ...
# 3    Canadian     White        Yes   44  ...
# 4      Korean     Asian         No   50  ...
#
#   Vous sentez-vous heureux au travail ? (1 à 10, 10 étant la meilleure note)  \
# 0                                                  4
# 1                                                  6
# 2                                                  9
# ...

# %%
data['Nationality'].unique()
# Out:
# array(['Polish', 'Lao', 'Canadian', 'Korean', 'English', 'Norwegian',
#        'Indian', 'Jordanian', 'Sri Lankan', 'British', 'Brazilian',
#        'American', 'Ukrainian', 'Mongolian', 'Malaysian', 'Chinese',
#        'Greek', 'Australian', 'Afghan', 'Icelandic', 'Costa Rican',
#        'Czech', 'Fijian', 'Moroccan', 'Bangladeshi', 'Hungarian',
#        'Colombian', 'Dominican', 'Zambian', 'Lebanese', 'Scottish',
#        'Latvian', 'Peruvian', 'Vietnamese', 'Nigerian', 'Russian',
#        'German', 'Chilean', 'Indonesian', 'Taiwanese', 'Cuban',
#        'Uruguayan', 'Guatemalan', 'Spanish', 'Thai', 'Japanese',
#        'Namibian', 'Danish', 'Irish', 'Malagasy', 'Bolivian', 'Honduran',
#        'Austrian', 'Romanian', 'Philippine', 'Dutch', 'South African',
#        'Batswana', 'Lithuanian', 'Venezuelan', 'Ghanaian', 'Iraqi',
#        'Jamaican', 'Paraguayan', 'Tongan', 'Libyan', 'Kuwaiti',
#        'Argentinian', 'Ecuadorian', 'Nepalese', 'Singaporean', 'French',
# ...

# %%
# Liste des nationalités
nationalities = ['Polish', 'Lao', 'Canadian', 'Korean', 'English', 'Norwegian',
                 'Indian', 'Jordanian', 'Sri Lankan', 'British', 'Brazilian',
                 'American', 'Ukrainian', 'Mongolian', 'Malaysian', 'Chinese',
                 'Greek', 'Australian', 'Afghan', 'Icelandic', 'Costa Rican',
                 'Czech', 'Fijian', 'Moroccan', 'Bangladeshi', 'Hungarian',
                 'Colombian', 'Dominican', 'Zambian', 'Lebanese', 'Scottish',
                 'Latvian', 'Peruvian', 'Vietnamese', 'Nigerian', 'Russian',
                 'German', 'Chilean', 'Indonesian', 'Taiwanese', 'Cuban',
                 'Uruguayan', 'Guatemalan', 'Spanish', 'Thai', 'Japanese',
                 'Namibian', 'Danish', 'Irish', 'Malagasy', 'Bolivian', 'Honduran',
                 'Austrian', 'Romanian', 'Philippine', 'Dutch', 'South African',
                 'Batswana', 'Lithuanian', 'Venezuelan', 'Ghanaian', 'Iraqi',
                 'Jamaican', 'Paraguayan', 'Tongan', 'Libyan', 'Kuwaiti',
                 'Argentinian', 'Ecuadorian', 'Nepalese', 'Singaporean', 'French',
                 'Zimbabwean', 'Mozambican', 'Tunisian', 'Nicaraguan', 'Egyptian',
                 'Mexican', 'Belgian', 'Kenyan', 'Croatian', 'Bulgarian', 'Slovak',
                 'Turkish', 'Tajikistani', 'Estonian', 'New Zealand', 'Maltese',
                 'Cambodian', 'Algerian', 'Cameroonian', 'Panamanian', 'Haitian',
                 'Pakistani', 'Salvadorian', 'Finnish', 'Ethiopian', 'Swedish',
                 'Syrian', 'Saudi', 'Welsh', 'Emirati', 'Serbian', 'Sudanese',
                 'Swiss', 'Israeli', 'Albanian', 'Senegalese', 'Portuguese',
                 'Italian', 'Malian', 'Iranian']

# Table de correspondance fictive nationalité -> pays
correspondance_nationalite_pays = {
    'Polish': 'Poland',
    'Lao': 'Laos',
    'Canadian': 'Canada',
    'Korean': 'South Korea',
    'English': 'United Kingdom',
    'Norwegian': 'Norway',
    'Indian': 'India',
    'Jordanian': 'Jordan',
    'Sri Lankan': 'Sri Lanka',
    'British': 'United Kingdom',
    'Brazilian': 'Brazil',
    'American': 'United States',
    'Ukrainian': 'Ukraine',
    'Mongolian': 'Mongolia',
    'Malaysian': 'Malaysia',
    'Chinese': 'China',
    'Greek': 'Greece',
    'Australian': 'Australia',
    'Afghan': 'Afghanistan',
    'Icelandic': 'Iceland',
    'Costa Rican': 'Costa Rica',
    'Czech': 'Czech Republic',
    'Fijian': 'Fiji',
    'Moroccan': 'Morocco',
    'Bangladeshi': 'Bangladesh',
    'Hungarian': 'Hungary',
    'Colombian': 'Colombia',
    'Dominican': 'Dominican Republic',
    'Zambian': 'Zambia',
    'Lebanese': 'Lebanon',
    'Scottish': 'United Kingdom',
    'Latvian': 'Latvia',
    'Peruvian': 'Peru',
    'Vietnamese': 'Vietnam',
    'Nigerian': 'Nigeria',
    'Russian': 'Russia',
    'German': 'Germany',
    'Chilean': 'Chile',
    'Indonesian': 'Indonesia',
    'Taiwanese': 'Taiwan',
    'Cuban': 'Cuba',
    'Uruguayan': 'Uruguay',
    'Guatemalan': 'Guatemala',
    'Spanish': 'Spain',
    'Thai': 'Thailand',
    'Japanese': 'Japan',
    'Namibian': 'Namibia',
    'Danish': 'Denmark',
    'Irish': 'Ireland',
    'Malagasy': 'Madagascar',
    'Bolivian': 'Bolivia',
    'Honduran': 'Honduras',
    'Austrian': 'Austria',
    'Romanian': 'Romania',
    'Philippine': 'Philippines',
    'Dutch': 'Netherlands',
    'South African': 'South Africa',
    'Batswana': 'Botswana',
    'Lithuanian': 'Lithuania',
    'Venezuelan': 'Venezuela',
    'Ghanaian': 'Ghana',
    'Iraqi': 'Iraq',
    'Jamaican': 'Jamaica',
    'Paraguayan': 'Paraguay',
    'Tongan': 'Tonga',
    'Libyan': 'Libya',
    'Kuwaiti': 'Kuwait',
    'Argentinian': 'Argentina',
    'Ecuadorian': 'Ecuador',
    'Nepalese': 'Nepal',
    'Singaporean': 'Singapore',
    'French': 'France',
    'Zimbabwean': 'Zimbabwe',
    'Mozambican': 'Mozambique',
    'Tunisian': 'Tunisia',
    'Nicaraguan': 'Nicaragua',
    'Egyptian': 'Egypt',
    'Mexican': 'Mexico',
    'Belgian': 'Belgium',
    'Kenyan': 'Kenya',
    'Croatian': 'Croatia',
    'Bulgarian': 'Bulgaria',
    'Slovak': 'Slovakia',
    'Turkish': 'Turkey',
    'Tajikistani': 'Tajikistan',
    'Estonian': 'Estonia',
    'New Zealand': 'New Zealand',
    'Maltese': 'Malta',
    'Cambodian': 'Cambodia',
    'Algerian': 'Algeria',
    'Cameroonian': 'Cameroon',
    'Panamanian': 'Panama',
    'Haitian': 'Haiti',
    'Pakistani': 'Pakistan',
    'Salvadorian': 'El Salvador',
    'Finnish': 'Finland',
    'Ethiopian': 'Ethiopia',
    'Swedish': 'Sweden',
    'Syrian': 'Syria',
    'Saudi': 'Saudi Arabia',
    'Welsh': 'Wales',
    'Emirati': 'United Arab Emirates',
    'Serbian': 'Serbia',
    'Sudanese': 'Sudan',
    'Swiss': 'Switzerland',
    'Israeli': 'Israel',
    'Albanian': 'Albania',
    'Senegalese': 'Senegal',
    'Portuguese': 'Portugal',
    'Italian': 'Italy',
    'Malian': 'Mali',
    'Iranian': 'Iran'
}

# Fonction pour obtenir le continent à partir du pays
def get_continent(country_name):
    continents = {
        'Poland': 'Europe',
        'Laos': 'Asia',
        'Canada': 'North America',
        'South Korea': 'Asia',
        'United Kingdom': 'Europe',
        'Norway': 'Europe',
        'India': 'Asia',
        'Jordan': 'Asia',
        'Sri Lanka': 'Asia',
        'Brazil': 'South America',
        'United States': 'North America',
        'Ukraine': 'Europe',
        'Mongolia': 'Asia',
        'Malaysia': 'Asia',
        'China': 'Asia',
        'Greece': 'Europe',
        'Australia': 'Australia',
        'Afghanistan': 'Asia',
        'Iceland': 'Europe',
        'Costa Rica': 'North America',
        'Czech Republic': 'Europe',
        'Fiji': 'Oceania',
        'Morocco': 'Africa',
        'Bangladesh': 'Asia',
        'Hungary': 'Europe',
        'Colombia': 'South America',
        'Dominican Republic': 'North America',
        'Zambia': 'Africa',
        'Lebanon': 'Asia',
        'Scotland': 'Europe',
        'Latvia': 'Europe',
        'Peru': 'South America',
        'Vietnam': 'Asia',
        'Nigeria': 'Africa',
        'Russia': 'Europe',
        'Germany': 'Europe',
        'Chile': 'South America',
        'Indonesia': 'Asia',
        'Taiwan': 'Asia',
        'Cuba': 'North America',
        'Uruguay': 'South America',
        'Guatemala': 'North America',
        'Spain': 'Europe',
        'Thailand': 'Asia',
        'Japan': 'Asia',
        'Namibia': 'Africa',
        'Denmark': 'Europe',
        'Ireland': 'Europe',
        'Madagascar': 'Africa',
        'Bolivia': 'South America',
        'Honduras': 'North America',
        'Austria': 'Europe',
        'Romania': 'Europe',
        'Philippines': 'Asia',
        'Netherlands': 'Europe',
        'South Africa': 'Africa',
        'Botswana': 'Africa',
        'Lithuania': 'Europe',
        'Venezuela': 'South America',
        'Ghana': 'Africa',
        'Iraq': 'Asia',
        'Jamaica': 'North America',
        'Paraguay': 'South America',
        'Tonga': 'Oceania',
        'Libya': 'Africa',
        'Kuwait': 'Asia',
        'Argentina': 'South America',
        'Ecuador': 'South America',
        'Nepal': 'Asia',
        'Singapore': 'Asia',
        'France': 'Europe',
        'Zimbabwe': 'Africa',
        'Mozambique': 'Africa',
        'Tunisia': 'Africa',
        'Nicaragua': 'North America',
        'Egypt': 'Africa',
        'Mexico': 'North America',
        'Belgium': 'Europe',
        'Kenya': 'Africa',
        'Croatia': 'Europe',
        'Bulgaria': 'Europe',
        'Slovakia': 'Europe',
        'Turkey': 'Asia',
        'Tajikistan': 'Asia',
        'Estonia': 'Europe',
        'New Zealand': 'Oceania',
        'Malta': 'Europe',
        'Cambodia': 'Asia',
        'Algeria': 'Africa',
        'Cameroon': 'Africa',
        'Panama': 'North America',
        'Haiti': 'North America',
        'Pakistan': 'Asia',
        'El Salvador': 'North America',
        'Finland': 'Europe',
        'Ethiopia': 'Africa',
        'Sweden': 'Europe',
        'Syria': 'Asia',
        'Saudi Arabia': 'Asia',
        'Wales': 'Europe',
        'United Arab Emirates': 'Asia',
        'Serbia': 'Europe',
        'Sudan': 'Africa',
        'Switzerland': 'Europe',
        'Israel': 'Asia',
        'Albania': 'Europe',
        'Senegal': 'Africa',
        'Portugal': 'Europe',
        'Italy': 'Europe',
        'Mali': 'Africa',
        'Iran': 'Asia'
    }
    return continents.get(country_name, 'Unknown')

# Ajout de la colonne 'Pays' en utilisant la table de correspondance
data['Pays'] = data['Nationality'].map(correspondance_nationalite_pays)

# Appliquer la fonction pour créer une nouvelle colonne "Continent"
data['Continent'] = data['Pays'].apply(get_continent)

# %%
data.head()
# Out:
#        Name   Surname   Division Manager       Gender              LGBTQ  \
# 0   Deborah   Addison         IT      No  Transgender  Prefer not to say
# 1      Mona      Hill  Marketing      No         Male                 No
# 2  Kimberly   Shelton    Finance      No       Female                 No
# 3     Denis  Robinson         HR      No         Male                 No
# 4    Carmen      Gunn         RD      No         Male                 No
#
#   Nationality Ethnicity Disability  Age  ...  \
# 0      Polish     White        Yes   29  ...
# 1         Lao     White         No   59  ...
# 2    Canadian     White         No   43  ...
# 3    Canadian     White        Yes   44  ...
# 4      Korean     Asian         No   50  ...
#
#   Comment évaluez-vous votre niveau de stress au travail ? (1 à 10, où 10 représente le plus faible niveau de stress)  \
# 0                                                  3
# 1                                                  6
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 38 columns):
#  #   Column                                                                                                                                                                           Non-Null Count  Dtype
# ---  ------                                                                                                                                                                           --------------  -----
#  0   Name                                                                                                                                                                             10000 non-null  object
#  1   Surname                                                                                                                                                                          10000 non-null  object
# ...

# %%
'''# Transformation des colonnes en booléens
columns_to_transform = [
    'Avez vous deja été victime/temoin de harcelement sexuel ?',
    'Avez vous deja été victime/temoin de discrimination raciale ?',
    'Avez-vous déjà été témoin ou victime de discrimination fondée sur le genre au travail ?',
    'Avez-vous déjà été témoin ou victime de discrimination fondée sur l\'âge au travail ?',
    'Avez-vous déjà été témoin ou victime de discrimination basée sur votre état de santé ou handicap au travail ?',
    'Vous sentez-vous respecté(e) et entendu(e) par vos collègues et votre hiérarchie ?',
    'Avez-vous déjà ressenti une situation de harcèlement moral ou psychologique au travail ?',
    'Vous sentez-vous en mesure de signaler en toute sécurité des préoccupations concernant des comportements inappropriés au travail ?'
]

# Conversion des réponses en booléens
data[columns_to_transform] = data[columns_to_transform].applymap(lambda x: x.lower() in ['oui', 'yes'])'''
# Out:
# "# Transformation des colonnes en booléens\ncolumns_to_transform = [\n    'Avez vous deja été victime/temoin de harcelement sexuel ?',\n    'Avez vous deja été victime/temoin de discrimination raciale ?',\n    'Avez-vous déjà été témoin ou victime de discrimination fondée sur le genre au travail ?',\n    'Avez-vous déjà été témoin ou victime de discrimination fondée sur l'âge au travail ?',\n    'Avez-vous déjà été témoin ou victime de discrimination basée sur votre état de santé ou handicap au travail ?',\n    'Vous sentez-vous respecté(e) et entendu(e) par vos collègues et votre hiérarchie ?',\n    'Avez-vous déjà ressenti une situation de harcèlement moral ou psychologique au travail ?',\n    'Vous sentez-vous en mesure de signaler en toute sécurité des préoccupations concernant des comportements inappropriés au travail ?'\n]\n\n# Conversion des réponses en booléens\ndata[columns_to_transform] = data[columns_to_transform].applymap(lambda x: x.lower() in ['oui', 'yes'])"

# %%
data.select_dtypes(include='number')
# Out:
#       Age  \
# 0      29
# 1      59
# 2      43
# 3      44
# 4      50
# ...   ...
# 9995   32
# 9996   37
# 9997   35
# 9998   62
# 9999   44
#
#       Dans le cas où vous avez déjà fait un signalement, comment jugez-vous le traitement de votre plainte ? (1 à 10, 10 étant totalement satisfait)  \
# 0                                                     7
# 1                                                     3
# 2                                                     5
# 3                                                     7
# 4                                                     5
# ...                                                 ...
# 9995                                                  8
# 9996                                                  9
# 9997                                                  6
# 9998                                                  7
# 9999                                                  7
#
# ...

# %%
data.loc[data['Gender'] == 'Other', 'Gender'] = 'Prefer not to say'

# %%
data['Gender'].value_counts()
# Out:
# Gender
# Male                         5902
# Female                       3388
# Prefer not to say             503
# Non-binary/non-conforming     110
# Transgender                    97
# Name: count, dtype: int64

# %%
w = data[data['Nationality']=='Chinese']
w
# Out:
#            Name  Surname    Division Manager  Gender LGBTQ Nationality  \
# 29     Nicholas   Cadman     Finance      No    Male    No     Chinese
# 57       Joseph  Gosling     Finance      No    Male    No     Chinese
# 102       Chuck     Hunt   Marketing      No  Female    No     Chinese
# 160         Zoe     Gray          HR      No  Female    No     Chinese
# 241       Sadie     Roth   Marketing      No  Female    No     Chinese
# ...         ...      ...         ...     ...     ...   ...         ...
# 9267      Dasha     Nash  Operations      No    Male   Yes     Chinese
# 9544      Tyson    Abbot   Marketing      No    Male    No     Chinese
# 9580       Tara   Murphy          HR      No    Male    No     Chinese
# 9678   Clarissa   Butler     Finance      No    Male    No     Chinese
# 9923  Alexander  Bullock       Sales      No    Male    No     Chinese
#
#      Ethnicity Disability  Age  ...  \
# 29       White        Yes   37  ...
# 57       White         No   30  ...
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 38 columns):
#  #   Column                                                                                                                                                                           Non-Null Count  Dtype
# ---  ------                                                                                                                                                                           --------------  -----
#  0   Name                                                                                                                                                                             10000 non-null  object
#  1   Surname                                                                                                                                                                          10000 non-null  object
# ...

# %%
# Calcul de la moyenne des colonnes spécifiques
cols_to_average = [
    "Dans le cas où vous avez déjà fait un signalement, comment jugez-vous le traitement de votre plainte ? (1 à 10, 10 étant totalement satisfait)",
    "Estimez-vous que l'égalité est respectée au sein de votre entreprise ? (1 à 10)",
    "Dans quelle mesure diriez-vous que votre entreprise valorise la diversité et l'inclusion ? (1 à 10)",
    "Vous sentez-vous apprécié pour le travail que vous accomplissez, indépendamment de votre identité sexuelle, de votre race, de votre handicap ou de votre nationalité ? (1 à 10)",
    "Vous sentez-vous heureux au travail ? (1 à 10, 10 étant la meilleure note)",
    "Vous sentez-vous en sécurité au travail ? (1 à 10, 10 étant la meilleure note)",
    "Comment évaluez-vous votre niveau de stress au travail ? (1 à 10, où 10 représente le plus faible niveau de stress)",
    "Comment évaluez-vous la qualité des relations avec vos collègues de travail ? (1 à 10, 10 étant la meilleure note)",
    "Recommanderiez-vous l’entreprise à un proche ? (1 à 10, 10 tout à fait)",
    "Vous sentez-vous respecté(e) et entendu(e) par vos collègues et votre hiérarchie ? (1 à 10)",
    "Pensez-vous que votre entreprise valorise et promeut activement un environnement de travail inclusif ? (1 à 10, 10 tout à fait)",
    "Pensez-vous que la direction et les managers de votre entreprise sont engagés et responsables en matière de diversité et d'inclusion ? (1 à 10, 10 tout à fait)"
]

# Calcul de la moyenne des colonnes spécifiées
data['Moyenne_Toutes_Colonnes'] = round(data[cols_to_average].mean(axis=1), 2)

# %%
data.head()
# Out:
#        Name   Surname   Division Manager       Gender              LGBTQ  \
# 0   Deborah   Addison         IT      No  Transgender  Prefer not to say
# 1      Mona      Hill  Marketing      No         Male                 No
# 2  Kimberly   Shelton    Finance      No       Female                 No
# 3     Denis  Robinson         HR      No         Male                 No
# 4    Carmen      Gunn         RD      No         Male                 No
#
#   Nationality Ethnicity Disability  Age  ...  \
# 0      Polish     White        Yes   29  ...
# 1         Lao     White         No   59  ...
# 2    Canadian     White         No   43  ...
# 3    Canadian     White        Yes   44  ...
# 4      Korean     Asian         No   50  ...
#
#   Comment évaluez-vous la qualité des relations avec vos collègues de travail ? (1 à 10, 10 étant la meilleure note)  \
# 0                                                  5
# 1                                                  8
# ...

# %%
data = data.to_csv('Data.csv')
